# %%
import os

# %%
##################################################################################
##### Define all parameters for model tuning
##################################################################################

n_fold = 10
expName = "MathFeature_setting1_kgap_fickett"
outPath = "Generated"

dataset_path = "CORENup-Datasets\\Datasets"
setting = "Setting1"

##################################################################################
##### Define the encoding hyperparameters
##################################################################################

# k-mer config
kmer = 7

# Tsallis Entropic Parameter
tep = 0

# threshold
th = 20

## sliding-window
sw = 10

## window-step
ws = 1

# %%
##################################################################################
##### Checking the directory
##################################################################################

dataset_setting_path = os.path.join(dataset_path, setting)
dataset_varieties = next(os.walk(dataset_setting_path))
print(dataset_varieties)
# Out:
# ('CORENup-Datasets\\Datasets\\Setting1', ['Drosophila', 'Elegans', 'Homo_Sapiens', 'Yeast'], [])

# %%
for root, dirs, files in os.walk(dataset_setting_path):
    for file in files:
        print((root, file))
# Out:
# ('CORENup-Datasets\\Datasets\\Setting1\\Drosophila', 'nucleosomes_vs_linkers_melanogaster.fas')
# ('CORENup-Datasets\\Datasets\\Setting1\\Elegans', 'nucleosomes_vs_linkers_elegans.fas')
# ('CORENup-Datasets\\Datasets\\Setting1\\Homo_Sapiens', 'nucleosomes_vs_linkers_sapiens.fas')
# ('CORENup-Datasets\\Datasets\\Setting1\\Yeast', 'nucleosomes_vs_linkers_yeast.fas')

# %% [markdown]
# ## Encodings

# %% [markdown]
# ### Preprocessing Step

# %%
##################################################################################
##### To eliminate any noise from the sequences (e.g., other letters as: N, K, …)
##################################################################################

out_path_datasets = os.path.join(outPath, expName, "Datasets")

for root, dirs, files in os.walk(dataset_setting_path):
    for file in files:
        
        current_dataset_variety = root.split("\\")[len(root.split("\\"))-1]
        
        read_file_full_path = os.path.join(root, file)
        write_file_path = root.replace(dataset_path, out_path_datasets)
        write_file_full_path = os.path.join(write_file_path, file)
        
        if(not os.path.isdir(write_file_path)):
            os.makedirs(write_file_path)
        
        command = "python MathFeature/preprocessing/preprocessing.py -i {} -o {}".format(read_file_full_path, write_file_full_path)
        # !{command}
# Out:
# nucleosomal_sequence_1
# Included Sequence
# nucleosomal_sequence_2
# Included Sequence
# nucleosomal_sequence_3
# Included Sequence
# nucleosomal_sequence_4
# Included Sequence
# nucleosomal_sequence_5
# Included Sequence
# nucleosomal_sequence_6
# Included Sequence
# nucleosomal_sequence_7
# Included Sequence
# nucleosomal_sequence_8
# Included Sequence
# nucleosomal_sequence_9
# Included Sequence
# nucleosomal_sequence_10
# Included Sequence
# nucleosomal_sequence_11
# Included Sequence
# nucleosomal_sequence_12
# Included Sequence
# nucleosomal_sequence_13
# Included Sequence
# nucleosomal_sequence_14
# Included Sequence
# nucleosomal_sequence_15
# Included Sequence
# nucleosomal_sequence_16
# Included Sequence
# nucleosomal_sequence_17
# Included Sequence
# nucleosomal_sequence_18
# Included Sequence
# nucleosomal_sequence_19
# Included Sequence
# nucleosomal_sequence_20
# Included Sequence
# nucleosomal_sequence_21
# Included Sequence
# nucleosomal_sequence_22
# ...

# %%
os.path.isdir("Generated\\MathFeatures_Setting1\\Datasets\\Setting1\\Drosophila")
# Out:
# False

# %%
os.path.isdir(os.path.join(os.getcwd(), "Generated\\MathFeatures_Setting1"))
# Out:
# False

# %% [markdown]
# #### Preprocessed file list

# %%
preprocessed_files_list = []
for root, dirs, files in os.walk(out_path_datasets):
    for file in files:
        preprocessed_files_list.append((root, file))

# %%
# preprocessed_files_list = [('Generated\\MathFeature_setting1\\Datasets\\Setting1\\Drosophila',
#   'nucleosomes_vs_linkers_melanogaster.fas'),
#  ('Generated\\MathFeature_setting1\\Datasets\\Setting1\\Elegans',
#   'nucleosomes_vs_linkers_elegans.fas'),
#  ('Generated\\MathFeature_setting1\\Datasets\\Setting1\\Homo_Sapiens',
#   'nucleosomes_vs_linkers_sapiens.fas'),
#  ('Generated\\MathFeature_setting1\\Datasets\\Setting1\\Yeast',
#   'nucleosomes_vs_linkers_yeast.fas')]

# %% [markdown]
# ### Numerical Mapping

# %%
# for (root, file) in preprocessed_files_list:
    
#     current_dataset_variety = root.split("\\")[len(root.split("\\"))-1]
#     input_file_full_path = os.path.join(root, file)

#     !python MathFeature/methods/MappingClass_Mod.py -i {input_file_full_path} -l {current_dataset_variety} -o {"_NM-binary.".join(input_file_full_path.split(".")).replace(".fas", ".csv")} -r 1
#     !python MathFeature/methods/MappingClass_Mod.py -i {input_file_full_path} -l {current_dataset_variety} -o {"_NM-zcurve.".join(input_file_full_path.split(".")).replace(".fas", ".csv")} -r 2
#     !python MathFeature/methods/MappingClass_Mod.py -i {input_file_full_path} -l {current_dataset_variety} -o {"_NM-real.".join(input_file_full_path.split(".")).replace(".fas", ".csv")} -r 3
#     !python MathFeature/methods/MappingClass_Mod.py -i {input_file_full_path} -l {current_dataset_variety} -o {"_NM-integer.".join(input_file_full_path.split(".")).replace(".fas", ".csv")} -r 4
#     !python MathFeature/methods/MappingClass_Mod.py -i {input_file_full_path} -l {current_dataset_variety} -o {"_NM-eiip.".join(input_file_full_path.split(".")).replace(".fas", ".csv")} -r 5
#     !python MathFeature/methods/MappingClass_Mod.py -i {input_file_full_path} -l {current_dataset_variety} -o {"_NM-complex.".join(input_file_full_path.split(".")).replace(".fas", ".csv")} -r 6
#     !python MathFeature/methods/MappingClass_Mod.py -i {input_file_full_path} -l {current_dataset_variety} -o {"_NM-atomic.".join(input_file_full_path.split(".")).replace(".fas", ".csv")} -r 7

# %% [markdown]
# ### Numerical Mapping - Fourier Transform

# %%
# for (root, file) in preprocessed_files_list:
    
#     current_dataset_variety = root.split("\\")[len(root.split("\\"))-1]
#     input_file_full_path = os.path.join(root, file)

#     !python MathFeature/methods/FourierClass_Mod.py -i {input_file_full_path} -l {current_dataset_variety} -o {"_NMFT-binary.".join(input_file_full_path.split(".")).replace(".fas", ".csv")} -r 1
#     !python MathFeature/methods/FourierClass_Mod.py -i {input_file_full_path} -l {current_dataset_variety} -o {"_NMFT-zcurve.".join(input_file_full_path.split(".")).replace(".fas", ".csv")} -r 2
#     !python MathFeature/methods/FourierClass_Mod.py -i {input_file_full_path} -l {current_dataset_variety} -o {"_NMFT-real.".join(input_file_full_path.split(".")).replace(".fas", ".csv")} -r 3
#     !python MathFeature/methods/FourierClass_Mod.py -i {input_file_full_path} -l {current_dataset_variety} -o {"_NMFT-integer.".join(input_file_full_path.split(".")).replace(".fas", ".csv")} -r 4
#     !python MathFeature/methods/FourierClass_Mod.py -i {input_file_full_path} -l {current_dataset_variety} -o {"_NMFT-eiip.".join(input_file_full_path.split(".")).replace(".fas", ".csv")} -r 5
#     !python MathFeature/methods/FourierClass_Mod.py -i {input_file_full_path} -l {current_dataset_variety} -o {"_NMFT-complex.".join(input_file_full_path.split(".")).replace(".fas", ".csv")} -r 6
#     !python MathFeature/methods/FourierClass_Mod.py -i {input_file_full_path} -l {current_dataset_variety} -o {"_NMFT-atomic.".join(input_file_full_path.split(".")).replace(".fas", ".csv")} -r 7

# %% [markdown]
# ### Chaos Game Representation

# %%
# ## some options use kmer

# for (root, file) in preprocessed_files_list:
    
#     current_dataset_variety = root.split("\\")[len(root.split("\\"))-1]
#     input_file_full_path = os.path.join(root, file)
    
#     !python MathFeature/methods/ChaosGameTheory_Mod.py -i {input_file_full_path} -l {current_dataset_variety} -o {"_Chaos-classic.".join(input_file_full_path.split(".")).replace(".fas", ".csv")} -r 1
#     !python MathFeature/methods/ChaosGameTheory_Mod.py -i {input_file_full_path} -l {current_dataset_variety} -o {"_Chaos-frequency.".join(input_file_full_path.split(".")).replace(".fas", ".csv")} -r 2 -f {kmer}
#     !python MathFeature/methods/ChaosGameTheory_Mod.py -i {input_file_full_path} -l {current_dataset_variety} -o {"_Chaos-classic-signal.".join(input_file_full_path.split(".")).replace(".fas", ".csv")} -r 3
#     !python MathFeature/methods/ChaosGameTheory_Mod.py -i {input_file_full_path} -l {current_dataset_variety} -o {"_Chaos-frequency-signal.".join(input_file_full_path.split(".")).replace(".fas", ".csv")} -r 4 -f {kmer}

# %% [markdown]
# ### Entropy - Shannon and Tsallis

# %% [markdown]
# #### Shannon

# %%
# ## uses kmer

# for (root, file) in preprocessed_files_list:
    
#     current_dataset_variety = root.split("\\")[len(root.split("\\"))-1]
#     input_file_full_path = os.path.join(root, file)
    
#     !python MathFeature/methods/EntropyClass_Mod.py -i {input_file_full_path} -l {current_dataset_variety} -o {"_Entropy-shannon.".join(input_file_full_path.split(".")).replace(".fas", ".csv")} -e Shannon -k {kmer}

# %% [markdown]
# #### Tsallis

# %%
# ## uses kmer, and tsallis entropic parameter

# for (root, file) in preprocessed_files_list:
    
#     current_dataset_variety = root.split("\\")[len(root.split("\\"))-1]
#     input_file_full_path = os.path.join(root, file)
    
#     !python MathFeature/methods/TsallisEntropy_Mod.py -i {input_file_full_path} -l {current_dataset_variety} -o {"_Entropy-tsallis.".join(input_file_full_path.split(".")).replace(".fas", ".csv")} -q {tep} -k {kmer}

# %% [markdown]
# ### Complex Networks

# %% [markdown]
# #### Version 1

# %%
# ## uses pattern (kmer) and threshold

# for (root, file) in preprocessed_files_list:
    
#     current_dataset_variety = root.split("\\")[len(root.split("\\"))-1]
#     input_file_full_path = os.path.join(root, file)
    
#     !python MathFeature/methods/ComplexNetworksClass_Mod.py -i {input_file_full_path} -l {current_dataset_variety} -o {"_Complex-Network.".join(input_file_full_path.split(".")).replace(".fas", ".csv")} -k {kmer} -t {th}

# %% [markdown]
# #### Version 2 - no threshold

# %%
# ## uses pattern (kmer)

# for (root, file) in preprocessed_files_list:
    
#     current_dataset_variety = root.split("\\")[len(root.split("\\"))-1]
#     input_file_full_path = os.path.join(root, file)
    
#     !python MathFeature/methods/ComplexNetworksClass-v2_Mod.py -i {input_file_full_path} -l {current_dataset_variety} -o {"_Complex-Network-v2.".join(input_file_full_path.split(".")).replace(".fas", ".csv")} -k {kmer}

# %% [markdown]
# ### Customizable k-mer, NAC, DNC, TNC

# %%
# ## uses kmer, sliding window, and window step

# for (root, file) in preprocessed_files_list:
    
#     current_dataset_variety = root.split("\\")[len(root.split("\\"))-1]
#     input_file_full_path = os.path.join(root, file)
    
#     !python MathFeature/methods/ExtractionTechniques_Mod.py -i {input_file_full_path} -l {current_dataset_variety} -o {"_NAC.".join(input_file_full_path.split(".")).replace(".fas", ".csv")} -seq 1 -t NAC
#     !python MathFeature/methods/ExtractionTechniques_Mod.py -i {input_file_full_path} -l {current_dataset_variety} -o {"_DNC.".join(input_file_full_path.split(".")).replace(".fas", ".csv")} -seq 1 -t DNC
#     !python MathFeature/methods/ExtractionTechniques_Mod.py -i {input_file_full_path} -l {current_dataset_variety} -o {"_TNC.".join(input_file_full_path.split(".")).replace(".fas", ".csv")} -seq 1 -t TNC
#     !python MathFeature/methods/ExtractionTechniques_Mod.py -i {input_file_full_path} -l {current_dataset_variety} -o {"_kmer.".join(input_file_full_path.split(".")).replace(".fas", ".csv")} -seq 1 -t kmer -k {kmer}
#     !python MathFeature/methods/ExtractionTechniques_Mod.py -i {input_file_full_path} -l {current_dataset_variety} -o {"_rckmer.".join(input_file_full_path.split(".")).replace(".fas", ".csv")} -seq 1 -t rckmer -k {kmer}
#     !python MathFeature/methods/ExtractionTechniques_Mod.py -i {input_file_full_path} -l {current_dataset_variety} -o {"_kstep.".join(input_file_full_path.split(".")).replace(".fas", ".csv")} -seq 1 -t kstep -k {kmer} -w {sw} -s {ws}

# %% [markdown]
# ### Accumulated Nucleotide Frequency (ANF)

# %%
# for (root, file) in preprocessed_files_list:
    
#     current_dataset_variety = root.split("\\")[len(root.split("\\"))-1]
#     input_file_full_path = os.path.join(root, file)
    
#     !python MathFeature/methods/AccumulatedNucleotideFrequency_Mod.py -i {input_file_full_path} -l {current_dataset_variety} -o {"_ANF.".join(input_file_full_path.split(".")).replace(".fas", ".csv")} -r 1
#     !python MathFeature/methods/AccumulatedNucleotideFrequency_Mod.py -i {input_file_full_path} -l {current_dataset_variety} -o {"_ANFF.".join(input_file_full_path.split(".")).replace(".fas", ".csv")} -r 2

# %% [markdown]
# ### Open Reading Frame (ORF) descriptor

# %%
# for (root, file) in preprocessed_files_list:
    
#     current_dataset_variety = root.split("\\")[len(root.split("\\"))-1]
#     input_file_full_path = os.path.join(root, file)
    
#     !python MathFeature/methods/CodingClass_Mod.py -i {input_file_full_path} -l {current_dataset_variety} -o {"_ORF.".join(input_file_full_path.split(".")).replace(".fas", ".csv")}

# %% [markdown]
# ### Fickett score

# %%
for (root, file) in preprocessed_files_list:
    
    current_dataset_variety = root.split("\\")[len(root.split("\\"))-1]
    input_file_full_path = os.path.join(root, file)
    
    # !python MathFeature/methods/FickettScore_Mod.py -i {input_file_full_path} -l {current_dataset_variety} -o {"_Fickett.".join(input_file_full_path.split(".")).replace(".fas", ".csv")} -seq 1
# Out:
# ###################################################################################
# ###############    Feature Extraction: Fickett Score - ORF  #######################
# ######        Arguments: -i input -o output -l label -seq DNA/RNA          ########
# ##########               Author: Robson Parmezan Bonidia                ###########
# ###################################################################################
#
#
#
#
# ###################################################################################
# ###############    Feature Extraction: Fickett Score - ORF  #######################
# ######        Arguments: -i input -o output -l label -seq DNA/RNA          ########
# ##########               Author: Robson Parmezan Bonidia                ###########
# ###################################################################################
#
#
#
#
# ###################################################################################
# ...

# %% [markdown]
# ### Pseudo k-tuple nucleotide composition - PseKNC

# %%
# for (root, file) in preprocessed_files_list:
    
#     current_dataset_variety = root.split("\\")[len(root.split("\\"))-1]
#     input_file_full_path = os.path.join(root, file)
    
#     !python MathFeature/methods/PseKNC_Mod.py -i {input_file_full_path} -l {current_dataset_variety} -o {"_PseKNC1-DN.".join(input_file_full_path.split(".")).replace(".fas", ".csv")} -x MathFeature/files/propNames-DNA-k2.txt -xp MathFeature/files/propValues-DNA-k2.txt -seq 1 -t 1 -k 2 -j 1 -w 1.0 -s 2
#     !python MathFeature/methods/PseKNC_Mod.py -i {input_file_full_path} -l {current_dataset_variety} -o {"_PseKNC2-DN.".join(input_file_full_path.split(".")).replace(".fas", ".csv")} -x MathFeature/files/propNames-DNA-k2.txt -xp MathFeature/files/propValues-DNA-k2.txt -seq 1 -t 2 -k 2 -j 1 -w 1.0 -s 2

#     !python MathFeature/methods/PseKNC_Mod.py -i {input_file_full_path} -l {current_dataset_variety} -o {"_PseKNC1-TN.".join(input_file_full_path.split(".")).replace(".fas", ".csv")} -x MathFeature/files/propNames-DNA-k3.txt -xp MathFeature/files/propValues-DNA-k3.txt -seq 1 -t 1 -k 3 -j 1 -w 1.0 -s 2
#     !python MathFeature/methods/PseKNC_Mod.py -i {input_file_full_path} -l {current_dataset_variety} -o {"_PseKNC2-TN.".join(input_file_full_path.split(".")).replace(".fas", ".csv")} -x MathFeature/files/propNames-DNA-k3.txt -xp MathFeature/files/propValues-DNA-k3.txt -seq 1 -t 2 -k 3 -j 1 -w 1.0 -s 2

# %% [markdown]
# ### Xmer k-Spaced Ymer Composition Frequency - kGap

# %%
for (root, file) in preprocessed_files_list:
    
    current_dataset_variety = root.split("\\")[len(root.split("\\"))-1]
    input_file_full_path = os.path.join(root, file)
    
    # !python MathFeature/methods/Kgap_Mod.py -i {input_file_full_path} -l {current_dataset_variety} -o {"_kgap.".join(input_file_full_path.split(".")).replace(".fas", ".csv")} -k 1 -bef 1 -aft 1 -seq 1
# Out:
# ###################################################################################
# ######################## Feature Extraction: k-gap scheme #########################
# ##########   Arguments: python3.5 -i input -o output -l label -k kmer   ###########
# #####   -seq type sequence -bef number before kgap -aft number after kgap   #######
# ###########               Author: Alvaro Pedroso Queiroz                ###########
# ###################################################################################
#
#
#
#
# ###################################################################################
# ######################## Feature Extraction: k-gap scheme #########################
# ##########   Arguments: python3.5 -i input -o output -l label -k kmer   ###########
# #####   -seq type sequence -bef number before kgap -aft number after kgap   #######
# ###########               Author: Alvaro Pedroso Queiroz                ###########
# ...

# %%
for (root, file) in preprocessed_files_list:
    
    current_dataset_variety = root.split("\\")[len(root.split("\\"))-1]
    input_file_full_path = os.path.join(root, file)
    
    # !python MathFeature/methods/Kgap_Mod.py -i {input_file_full_path} -l {current_dataset_variety} -o {"_kgap_test.".join(input_file_full_path.split(".")).replace(".fas", ".csv")} -k 2 -bef 2 -aft 2 -seq 1
# Out:
# ###################################################################################
# ######################## Feature Extraction: k-gap scheme #########################
# ##########   Arguments: python3.5 -i input -o output -l label -k kmer   ###########
# #####   -seq type sequence -bef number before kgap -aft number after kgap   #######
# ###########               Author: Alvaro Pedroso Queiroz                ###########
# ###################################################################################
#
#
#
#
# ###################################################################################
# ######################## Feature Extraction: k-gap scheme #########################
# ##########   Arguments: python3.5 -i input -o output -l label -k kmer   ###########
# #####   -seq type sequence -bef number before kgap -aft number after kgap   #######
# ###########               Author: Alvaro Pedroso Queiroz                ###########
# ...
